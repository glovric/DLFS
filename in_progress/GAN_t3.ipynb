# %%
from dlfs.base import Module, Loss
from dlfs.layers import DenseLayer, ReshapeLayer, ConvLayer, ConvTransposeLayer, BatchNorm2D, DropoutLayer
from dlfs.activation import ReLU, LeakyReLU, Tanh, Sigmoid
from dlfs.modules import SequentialWrapper
from dlfs.helpers import DLFSData, get_random_batch
from dlfs.optimizers import Optimizer_Adam
from dlfs.loss import BCE_Loss, MSE_Loss

import numpy as np
import matplotlib.pyplot as plt

# %%
class DCGenerator(Module):

    def __init__(self, latent_dim, features):

        self.latent_dim = latent_dim
        self.features = features
    
        self.model = SequentialWrapper([

                # Z → (ngf*4) × 4 × 4
                ConvTransposeLayer(
                    input_channels=latent_dim,
                    output_channels=features * 4,
                    kernel_size=4,
                    stride=1,
                    padding=0
                ),
                BatchNorm2D(features * 4),
                ReLU(),

                # 4×4 → 7×7
                ConvTransposeLayer(
                    input_channels=features * 4,
                    output_channels=features * 2,
                    kernel_size=3,
                    stride=2,
                    padding=1
                ),
                BatchNorm2D(features * 2),
                ReLU(),

                # 7×7 → 14×14
                ConvTransposeLayer(
                    input_channels=features * 2,
                    output_channels=features,
                    kernel_size=4,
                    stride=2,
                    padding=1
                ),
                BatchNorm2D(features),
                ReLU(),

                # 14×14 → 28×28  (final MNIST resolution)
                ConvTransposeLayer(
                    input_channels=features,
                    output_channels=1,
                    kernel_size=4,
                    stride=2,
                    padding=1
                ),

                #Sigmoid()
            ])

    def forward(self, x, training=False):
        self.model.forward(x, training=training)
        self.output = self.model.output

    def backward(self, delta):
        self.model.backward(delta)
        self.dinputs = self.model.dinputs.copy()

# %%
class DCDiscriminator(Module):

    def __init__(self, features):

        self.features = features

        self.model = SequentialWrapper([
                ConvLayer(input_channels=1, output_channels=features, kernel_size=4, stride=2, padding=1),
                LeakyReLU(0.2),

                ConvLayer(input_channels=features, output_channels=features*2, kernel_size=4, stride=2, padding=1),
                #BatchNorm2D(features*2),
                LeakyReLU(0.2),

                ConvLayer(input_channels=features*2, output_channels=features*4, kernel_size=3, stride=2, padding=1),
                #BatchNorm2D(features*4),
                LeakyReLU(0.2),

                ConvLayer(input_channels=features*4, output_channels=1, kernel_size=4, stride=1, padding=0),
                ReshapeLayer(input_shape=(1, 1, 1), output_shape=(1, )),
                #Sigmoid()
        ])
    
    def forward(self, x, training=False):
        self.model.forward(x, training=training)
        self.output = self.model.output

    def backward(self, delta):
        self.model.backward(delta)
        self.dinputs = self.model.dinputs.copy()

# %%
class GAN(Module):

    def __init__(self, generator, discriminator, loss_fn, optimizer_g, optimizer_d):
        self.generator = generator
        self.discriminator = discriminator
        self.loss_fn = loss_fn
        self.optimizer_g = optimizer_g
        self.optimizer_d = optimizer_d

    def _generator_forward_step(self, batch_size: int, real_labels: np.ndarray, training=False):
        # Create random latent variables
        z = np.random.randn(batch_size, self.generator.latent_dim, 1, 1)
        #z = np.random.uniform(low=-1.0, high=1.0, size=(batch_size, self.generator.latent_dim))

        # Generate fake samples
        self.generator.forward(z, training=training)
        generated_fake = self.generator.output.copy()

        # Let discriminator guess
        self.discriminator.forward(generated_fake, training=training)
        discriminator_output = self.discriminator.output.copy() #(B, 1)

        # Calculate generator loss (compare fake with real)
        generator_loss = self.loss_fn.calculate(discriminator_output, real_labels)

        return generator_loss, discriminator_output.copy()

    def _generator_backward_step(self, discriminator_output, real_labels):
        self.loss_fn.backward(discriminator_output, real_labels)
        #print(f'loss fn sat grad: {np.linalg.norm(self.loss_fn_sat.dinputs)}')
        self.discriminator.backward(self.loss_fn.dinputs)
        #print(f'discriminator grad: {np.linalg.norm(self.discriminator.dinputs)}')
        self.generator.backward(self.discriminator.dinputs)
        #print(f'generator grad: {np.linalg.norm(self.generator.dinputs)}')

    def _discriminator_forward_step(self, X, real_labels: np.ndarray, fake_labels: np.ndarray, noise=0.1, training=False):

        batch_size = X.shape[0]

        # Create random latent variables
        z = np.random.randn(batch_size, self.generator.latent_dim, 1, 1)
        #z = np.random.uniform(low=-1.0, high=1.0, size=(batch_size, self.generator.latent_dim))

        # Generate fake samples
        self.generator.forward(z, training=training)
        generated_fake = self.generator.output.copy()

        # Combine real and fake samples
        X_combined = np.concatenate([X, generated_fake])
        y_combined = np.concatenate([real_labels, fake_labels]) 

        idx = np.random.permutation(len(X_combined))
        X_combined = X_combined[idx]
        y_combined = y_combined[idx]

        X_combined += np.random.randn(*X_combined.shape) * noise

        # Let discriminator guess both real and fake
        self.discriminator.forward(X_combined, training=training)
        combined_output = self.discriminator.output.copy() #(B, 1)

        #print(f'disc output: {combined_output.shape}')

        # Calculate discriminator loss
        discriminator_loss = self.loss_fn.calculate(combined_output, y_combined)
        return discriminator_loss, combined_output.copy(), y_combined.copy()

    def _discriminator_backward_step(self, discriminator_output, labels):
        self.loss_fn.backward(discriminator_output, labels)
        self.discriminator.backward(self.loss_fn.dinputs)
    
    def train(self, X: np.ndarray, epochs: int = 1000, batch_size: int = None, print_every: int = None) -> None:

        for i in range(epochs + 1):

            if batch_size is None:
                batch_size = X.shape[0]

            X_batch = get_random_batch(X, batch_size=batch_size)[0]
            b_size = X_batch.shape[0]  # actual batch size

            # Labels
            real = np.ones((b_size, 1))
            fake = np.zeros((b_size, 1))

            # Discriminator forward-backward step
            dis_loss, dis_out, combined_labels = self._discriminator_forward_step(X_batch, real * 0.9, fake, noise=0.1, training=True)
            self._discriminator_backward_step(dis_out, combined_labels)

            # Discriminator parameter update
            self.optimizer_d.pre_update_parameters()
            self.optimizer_d.update_parameters(self.discriminator)
            self.optimizer_d.post_update_parameters()

            # Train generator twice per epoch
            for _ in range(1):
                
                # Generator forward-backward step
                gen_loss, dis_out = self._generator_forward_step(b_size, real, training=True)
                self._generator_backward_step(dis_out, real)

                # Generator parameter update
                self.optimizer_g.pre_update_parameters()
                self.optimizer_g.update_parameters(self.generator)
                self.optimizer_g.post_update_parameters()

            if print_every is not None:

                real = np.ones((X.shape[0], 1))
                fake = np.zeros((X.shape[0], 1))

                # Validation Gen
                gen_loss, dis_out = self._generator_forward_step(X.shape[0], real)

                # Validation Disc
                dis_loss, dis_out, combined_labels = self._discriminator_forward_step(X, real, fake, noise=0.0)

                if not i % print_every:
                    print(f'===== EPOCH : {i} ===== LOSS DIS : {dis_loss:.5f} ===== LOSS GEN : {gen_loss:.5f}')

# %% [markdown]
# # Load data

# %%
np.random.seed(1)

mnist_path = "../data/mnist"

X_train, y_train, X_test, y_test = DLFSData.load_MNIST(mnist_path)

print(f'X_train: {X_train.shape}, y_train: {y_train.shape}')
print(f'X_test: {X_test.shape}, y_test: {y_test.shape}')
# Out:
# X_train: (60000, 28, 28), y_train: (60000,)
# X_test: (10000, 28, 28), y_test: (10000,)

# %%
# Selecting images of 3s and 7s
X_train, _ = DLFSData.select_MNIST_labels(X_train, y_train, labels=[0, 1, 2, 3], limit=50, shuffle=True)
X_train = DLFSData.normalize_MNIST(X_train, range=(-1, 1))

X_train = X_train.reshape(-1, 1, 28, 28)
print(f'X_train: {X_train.shape}')
# Out:
# X_train: (200, 1, 28, 28)

# %%
latent_dim = 100 # 100 radi
generator_features = 64 # 64 generator
discriminator_features = 32 # 32 discriminator

lr = 2e-3 # 2e-3
epochs = 500
batch_size = 100 # 64 radi

gen = DCGenerator(latent_dim=latent_dim, features=generator_features)
dis = DCDiscriminator(features=discriminator_features)

gan = GAN(generator=gen, 
          discriminator=dis, 
          loss_fn=BCE_Loss(from_logits=True),
          optimizer_g=Optimizer_Adam(learning_rate=lr, beta_1=0.5),
          optimizer_d=Optimizer_Adam(learning_rate=lr, beta_1=0.5)) # beta1=0.5 !!

gan.train(X_train, epochs=epochs, print_every=1, batch_size=batch_size)
# Out:
# ===== EPOCH : 0 ===== LOSS DIS : 0.63795 ===== LOSS GEN : 0.50533
# ===== EPOCH : 1 ===== LOSS DIS : 0.57684 ===== LOSS GEN : 0.55731
# ===== EPOCH : 2 ===== LOSS DIS : 0.52413 ===== LOSS GEN : 0.71005
# ===== EPOCH : 3 ===== LOSS DIS : 0.46871 ===== LOSS GEN : 0.72099
# ===== EPOCH : 4 ===== LOSS DIS : 0.48909 ===== LOSS GEN : 0.84866
# ===== EPOCH : 5 ===== LOSS DIS : 0.83042 ===== LOSS GEN : 0.21857
# ===== EPOCH : 6 ===== LOSS DIS : 0.73478 ===== LOSS GEN : 0.54226
# ===== EPOCH : 7 ===== LOSS DIS : 0.54009 ===== LOSS GEN : 0.65541
# ===== EPOCH : 8 ===== LOSS DIS : 0.46163 ===== LOSS GEN : 0.72030
# ===== EPOCH : 9 ===== LOSS DIS : 0.50991 ===== LOSS GEN : 0.69147
# ===== EPOCH : 10 ===== LOSS DIS : 0.54338 ===== LOSS GEN : 0.60162
# ===== EPOCH : 11 ===== LOSS DIS : 0.49404 ===== LOSS GEN : 0.67324
# ===== EPOCH : 12 ===== LOSS DIS : 0.50489 ===== LOSS GEN : 0.81341
# ===== EPOCH : 13 ===== LOSS DIS : 0.48375 ===== LOSS GEN : 0.60737
# ===== EPOCH : 14 ===== LOSS DIS : 0.58910 ===== LOSS GEN : 0.82166
# ===== EPOCH : 15 ===== LOSS DIS : 0.55090 ===== LOSS GEN : 0.47285
# ===== EPOCH : 16 ===== LOSS DIS : 0.61585 ===== LOSS GEN : 0.85938
# ===== EPOCH : 17 ===== LOSS DIS : 0.57056 ===== LOSS GEN : 0.47240
# ===== EPOCH : 18 ===== LOSS DIS : 0.53841 ===== LOSS GEN : 0.73919
# ===== EPOCH : 19 ===== LOSS DIS : 0.59287 ===== LOSS GEN : 0.73447
# ===== EPOCH : 20 ===== LOSS DIS : 0.65429 ===== LOSS GEN : 0.46864
# ===== EPOCH : 21 ===== LOSS DIS : 1.19827 ===== LOSS GEN : 1.77756
# ===== EPOCH : 22 ===== LOSS DIS : 0.71400 ===== LOSS GEN : 0.31489
# ===== EPOCH : 23 ===== LOSS DIS : 0.59668 ===== LOSS GEN : 0.45318
# ===== EPOCH : 24 ===== LOSS DIS : 0.54807 ===== LOSS GEN : 0.62047
# ===== EPOCH : 25 ===== LOSS DIS : 0.54795 ===== LOSS GEN : 0.73376
# ===== EPOCH : 26 ===== LOSS DIS : 0.56809 ===== LOSS GEN : 0.78584
# ===== EPOCH : 27 ===== LOSS DIS : 0.63281 ===== LOSS GEN : 0.69178
# ===== EPOCH : 28 ===== LOSS DIS : 0.68757 ===== LOSS GEN : 0.60804
# ===== EPOCH : 29 ===== LOSS DIS : 0.68747 ===== LOSS GEN : 0.61438
# ===== EPOCH : 30 ===== LOSS DIS : 0.65425 ===== LOSS GEN : 0.66024
# ===== EPOCH : 31 ===== LOSS DIS : 0.63889 ===== LOSS GEN : 0.65077
# ===== EPOCH : 32 ===== LOSS DIS : 0.63812 ===== LOSS GEN : 0.64124
# ===== EPOCH : 33 ===== LOSS DIS : 0.59424 ===== LOSS GEN : 0.73580
# ===== EPOCH : 34 ===== LOSS DIS : 0.53451 ===== LOSS GEN : 0.85243
# ===== EPOCH : 35 ===== LOSS DIS : 0.59244 ===== LOSS GEN : 0.65792
# ===== EPOCH : 36 ===== LOSS DIS : 0.62102 ===== LOSS GEN : 0.70804
# ===== EPOCH : 37 ===== LOSS DIS : 0.52660 ===== LOSS GEN : 0.88060
# ===== EPOCH : 38 ===== LOSS DIS : 0.55302 ===== LOSS GEN : 0.77576
# ===== EPOCH : 39 ===== LOSS DIS : 0.63631 ===== LOSS GEN : 0.71072
# ===== EPOCH : 40 ===== LOSS DIS : 0.63095 ===== LOSS GEN : 0.76441
# ===== EPOCH : 41 ===== LOSS DIS : 0.53133 ===== LOSS GEN : 0.80771
# ===== EPOCH : 42 ===== LOSS DIS : 0.49951 ===== LOSS GEN : 0.91785
# ===== EPOCH : 43 ===== LOSS DIS : 0.52095 ===== LOSS GEN : 0.79009
# ===== EPOCH : 44 ===== LOSS DIS : 0.56184 ===== LOSS GEN : 0.95280
# ===== EPOCH : 45 ===== LOSS DIS : 0.72770 ===== LOSS GEN : 0.34182
# ===== EPOCH : 46 ===== LOSS DIS : 1.28361 ===== LOSS GEN : 2.66734
# ===== EPOCH : 47 ===== LOSS DIS : 0.51435 ===== LOSS GEN : 0.62405
# ===== EPOCH : 48 ===== LOSS DIS : 0.55250 ===== LOSS GEN : 0.54605
# ===== EPOCH : 49 ===== LOSS DIS : 0.51707 ===== LOSS GEN : 0.64244
# ===== EPOCH : 50 ===== LOSS DIS : 0.50768 ===== LOSS GEN : 0.79702
# ===== EPOCH : 51 ===== LOSS DIS : 0.52593 ===== LOSS GEN : 0.95611
# ===== EPOCH : 52 ===== LOSS DIS : 0.55789 ===== LOSS GEN : 0.98393
# ===== EPOCH : 53 ===== LOSS DIS : 0.63712 ===== LOSS GEN : 0.82656
# ===== EPOCH : 54 ===== LOSS DIS : 0.77968 ===== LOSS GEN : 0.60701
# ===== EPOCH : 55 ===== LOSS DIS : 0.78354 ===== LOSS GEN : 0.77434
# ===== EPOCH : 56 ===== LOSS DIS : 0.68286 ===== LOSS GEN : 1.07770
# ===== EPOCH : 57 ===== LOSS DIS : 0.59189 ===== LOSS GEN : 1.08710
# ===== EPOCH : 58 ===== LOSS DIS : 0.52889 ===== LOSS GEN : 0.94198
# ===== EPOCH : 59 ===== LOSS DIS : 0.49444 ===== LOSS GEN : 0.85994
# ===== EPOCH : 60 ===== LOSS DIS : 0.48903 ===== LOSS GEN : 0.84403
# ===== EPOCH : 61 ===== LOSS DIS : 0.51350 ===== LOSS GEN : 0.81627
# ===== EPOCH : 62 ===== LOSS DIS : 0.58227 ===== LOSS GEN : 0.73920
# ===== EPOCH : 63 ===== LOSS DIS : 0.60402 ===== LOSS GEN : 0.73440
# ===== EPOCH : 64 ===== LOSS DIS : 0.54080 ===== LOSS GEN : 0.96124
# ===== EPOCH : 65 ===== LOSS DIS : 0.50298 ===== LOSS GEN : 0.96725
# ===== EPOCH : 66 ===== LOSS DIS : 0.49019 ===== LOSS GEN : 1.11903
# ===== EPOCH : 67 ===== LOSS DIS : 0.49443 ===== LOSS GEN : 1.39881
# ===== EPOCH : 68 ===== LOSS DIS : 0.54843 ===== LOSS GEN : 1.16933
# ===== EPOCH : 69 ===== LOSS DIS : 0.76536 ===== LOSS GEN : 1.28092
# ===== EPOCH : 70 ===== LOSS DIS : 0.82144 ===== LOSS GEN : 0.53797
# ===== EPOCH : 71 ===== LOSS DIS : 0.77184 ===== LOSS GEN : 1.63694
# ===== EPOCH : 72 ===== LOSS DIS : 0.63732 ===== LOSS GEN : 0.79757
# ===== EPOCH : 73 ===== LOSS DIS : 0.49503 ===== LOSS GEN : 0.96616
# ===== EPOCH : 74 ===== LOSS DIS : 0.47548 ===== LOSS GEN : 1.07001
# ===== EPOCH : 75 ===== LOSS DIS : 0.52579 ===== LOSS GEN : 0.81218
# ===== EPOCH : 76 ===== LOSS DIS : 0.57272 ===== LOSS GEN : 0.88104
# ===== EPOCH : 77 ===== LOSS DIS : 0.56847 ===== LOSS GEN : 0.92344
# ===== EPOCH : 78 ===== LOSS DIS : 0.52728 ===== LOSS GEN : 0.89280
# ===== EPOCH : 79 ===== LOSS DIS : 0.50117 ===== LOSS GEN : 1.32906
# ===== EPOCH : 80 ===== LOSS DIS : 0.55754 ===== LOSS GEN : 0.62979
# ===== EPOCH : 81 ===== LOSS DIS : 0.50561 ===== LOSS GEN : 1.68530
# ===== EPOCH : 82 ===== LOSS DIS : 0.66058 ===== LOSS GEN : 0.51626
# ===== EPOCH : 83 ===== LOSS DIS : 0.61196 ===== LOSS GEN : 2.10461
# ===== EPOCH : 84 ===== LOSS DIS : 0.59508 ===== LOSS GEN : 0.81888
# ===== EPOCH : 85 ===== LOSS DIS : 0.45287 ===== LOSS GEN : 1.54997
# ===== EPOCH : 86 ===== LOSS DIS : 0.39383 ===== LOSS GEN : 1.52187
# ===== EPOCH : 87 ===== LOSS DIS : 0.40132 ===== LOSS GEN : 1.06262
# ===== EPOCH : 88 ===== LOSS DIS : 0.45547 ===== LOSS GEN : 1.08698
# ===== EPOCH : 89 ===== LOSS DIS : 0.59123 ===== LOSS GEN : 1.09146
# ===== EPOCH : 90 ===== LOSS DIS : 0.66188 ===== LOSS GEN : 1.44449
# ===== EPOCH : 91 ===== LOSS DIS : 0.75129 ===== LOSS GEN : 0.64276
# ===== EPOCH : 92 ===== LOSS DIS : 0.57335 ===== LOSS GEN : 1.43492
# ===== EPOCH : 93 ===== LOSS DIS : 0.47954 ===== LOSS GEN : 1.06404
# ===== EPOCH : 94 ===== LOSS DIS : 0.51021 ===== LOSS GEN : 0.86166
# ===== EPOCH : 95 ===== LOSS DIS : 0.52139 ===== LOSS GEN : 1.39934
# ===== EPOCH : 96 ===== LOSS DIS : 0.55567 ===== LOSS GEN : 0.76918
# ===== EPOCH : 97 ===== LOSS DIS : 0.57129 ===== LOSS GEN : 1.65416
# ===== EPOCH : 98 ===== LOSS DIS : 0.62017 ===== LOSS GEN : 0.63489
# ===== EPOCH : 99 ===== LOSS DIS : 0.56193 ===== LOSS GEN : 1.38424
# ===== EPOCH : 100 ===== LOSS DIS : 0.53644 ===== LOSS GEN : 0.87684
# ===== EPOCH : 101 ===== LOSS DIS : 0.45750 ===== LOSS GEN : 1.28373
# ===== EPOCH : 102 ===== LOSS DIS : 0.42220 ===== LOSS GEN : 1.24367
# ===== EPOCH : 103 ===== LOSS DIS : 0.40953 ===== LOSS GEN : 1.23721
# ===== EPOCH : 104 ===== LOSS DIS : 0.45930 ===== LOSS GEN : 1.24886
# ===== EPOCH : 105 ===== LOSS DIS : 0.61774 ===== LOSS GEN : 1.11724
# ===== EPOCH : 106 ===== LOSS DIS : 0.61018 ===== LOSS GEN : 1.07401
# ===== EPOCH : 107 ===== LOSS DIS : 0.57924 ===== LOSS GEN : 0.92035
# ===== EPOCH : 108 ===== LOSS DIS : 0.58735 ===== LOSS GEN : 1.14841
# ===== EPOCH : 109 ===== LOSS DIS : 0.61925 ===== LOSS GEN : 0.83324
# ===== EPOCH : 110 ===== LOSS DIS : 0.62254 ===== LOSS GEN : 0.90627
# ===== EPOCH : 111 ===== LOSS DIS : 0.61673 ===== LOSS GEN : 0.89636
# ===== EPOCH : 112 ===== LOSS DIS : 0.55206 ===== LOSS GEN : 1.00703
# ===== EPOCH : 113 ===== LOSS DIS : 0.52124 ===== LOSS GEN : 1.07583
# ===== EPOCH : 114 ===== LOSS DIS : 0.54944 ===== LOSS GEN : 1.48755
# ===== EPOCH : 115 ===== LOSS DIS : 0.93550 ===== LOSS GEN : 0.21908
# ===== EPOCH : 116 ===== LOSS DIS : 1.38545 ===== LOSS GEN : 3.91173
# ===== EPOCH : 117 ===== LOSS DIS : 0.51291 ===== LOSS GEN : 0.99032
# ===== EPOCH : 118 ===== LOSS DIS : 0.55245 ===== LOSS GEN : 0.62922
# ===== EPOCH : 119 ===== LOSS DIS : 0.49768 ===== LOSS GEN : 0.73297
# ===== EPOCH : 120 ===== LOSS DIS : 0.45763 ===== LOSS GEN : 1.00608
# ===== EPOCH : 121 ===== LOSS DIS : 0.45209 ===== LOSS GEN : 1.19103
# ===== EPOCH : 122 ===== LOSS DIS : 0.48230 ===== LOSS GEN : 1.16899
# ===== EPOCH : 123 ===== LOSS DIS : 0.53572 ===== LOSS GEN : 0.97240
# ===== EPOCH : 124 ===== LOSS DIS : 0.58737 ===== LOSS GEN : 0.95211
# ===== EPOCH : 125 ===== LOSS DIS : 0.57023 ===== LOSS GEN : 1.07789
# ===== EPOCH : 126 ===== LOSS DIS : 0.58364 ===== LOSS GEN : 1.11070
# ===== EPOCH : 127 ===== LOSS DIS : 0.56653 ===== LOSS GEN : 1.02324
# ===== EPOCH : 128 ===== LOSS DIS : 0.54553 ===== LOSS GEN : 0.92648
# ===== EPOCH : 129 ===== LOSS DIS : 0.52940 ===== LOSS GEN : 0.92898
# ===== EPOCH : 130 ===== LOSS DIS : 0.56860 ===== LOSS GEN : 0.95659
# ===== EPOCH : 131 ===== LOSS DIS : 0.56781 ===== LOSS GEN : 0.91077
# ===== EPOCH : 132 ===== LOSS DIS : 0.51956 ===== LOSS GEN : 0.97052
# ===== EPOCH : 133 ===== LOSS DIS : 0.48072 ===== LOSS GEN : 0.97458
# ===== EPOCH : 134 ===== LOSS DIS : 0.47506 ===== LOSS GEN : 0.98731
# ===== EPOCH : 135 ===== LOSS DIS : 0.45537 ===== LOSS GEN : 1.15233
# ===== EPOCH : 136 ===== LOSS DIS : 0.41338 ===== LOSS GEN : 1.07154
# ===== EPOCH : 137 ===== LOSS DIS : 0.35528 ===== LOSS GEN : 1.42453
# ===== EPOCH : 138 ===== LOSS DIS : 0.36858 ===== LOSS GEN : 1.31783
# ===== EPOCH : 139 ===== LOSS DIS : 0.45014 ===== LOSS GEN : 1.01359
# ===== EPOCH : 140 ===== LOSS DIS : 0.52667 ===== LOSS GEN : 1.73711
# ===== EPOCH : 141 ===== LOSS DIS : 0.66659 ===== LOSS GEN : 0.45426
# ===== EPOCH : 142 ===== LOSS DIS : 0.56114 ===== LOSS GEN : 2.31324
# ===== EPOCH : 143 ===== LOSS DIS : 0.40756 ===== LOSS GEN : 1.19629
# ===== EPOCH : 144 ===== LOSS DIS : 0.40717 ===== LOSS GEN : 0.96075
# ===== EPOCH : 145 ===== LOSS DIS : 0.38745 ===== LOSS GEN : 1.29571
# ===== EPOCH : 146 ===== LOSS DIS : 0.42009 ===== LOSS GEN : 1.27405
# ===== EPOCH : 147 ===== LOSS DIS : 0.41256 ===== LOSS GEN : 1.19865
# ===== EPOCH : 148 ===== LOSS DIS : 0.43660 ===== LOSS GEN : 1.10639
# ===== EPOCH : 149 ===== LOSS DIS : 0.45206 ===== LOSS GEN : 1.11797
# ===== EPOCH : 150 ===== LOSS DIS : 0.45148 ===== LOSS GEN : 1.27185
# ===== EPOCH : 151 ===== LOSS DIS : 0.43152 ===== LOSS GEN : 1.25839
# ===== EPOCH : 152 ===== LOSS DIS : 0.44123 ===== LOSS GEN : 1.12160
# ===== EPOCH : 153 ===== LOSS DIS : 0.47955 ===== LOSS GEN : 1.05547
# ===== EPOCH : 154 ===== LOSS DIS : 0.48026 ===== LOSS GEN : 1.02640
# ===== EPOCH : 155 ===== LOSS DIS : 0.43985 ===== LOSS GEN : 1.04015
# ===== EPOCH : 156 ===== LOSS DIS : 0.40384 ===== LOSS GEN : 1.00352
# ===== EPOCH : 157 ===== LOSS DIS : 0.38721 ===== LOSS GEN : 1.67537
# ===== EPOCH : 158 ===== LOSS DIS : 0.49276 ===== LOSS GEN : 0.68190
# ===== EPOCH : 159 ===== LOSS DIS : 0.64382 ===== LOSS GEN : 2.90792
# ===== EPOCH : 160 ===== LOSS DIS : 0.98814 ===== LOSS GEN : 0.26901
# ===== EPOCH : 161 ===== LOSS DIS : 0.49438 ===== LOSS GEN : 1.65522
# ===== EPOCH : 162 ===== LOSS DIS : 0.49696 ===== LOSS GEN : 1.65151
# ===== EPOCH : 163 ===== LOSS DIS : 0.45011 ===== LOSS GEN : 1.03943
# ===== EPOCH : 164 ===== LOSS DIS : 0.39212 ===== LOSS GEN : 1.19694
# ===== EPOCH : 165 ===== LOSS DIS : 0.37857 ===== LOSS GEN : 1.54986
# ===== EPOCH : 166 ===== LOSS DIS : 0.37683 ===== LOSS GEN : 1.22019
# ===== EPOCH : 167 ===== LOSS DIS : 0.36205 ===== LOSS GEN : 1.34948
# ===== EPOCH : 168 ===== LOSS DIS : 0.37288 ===== LOSS GEN : 1.23448
# ===== EPOCH : 169 ===== LOSS DIS : 0.42807 ===== LOSS GEN : 1.07948
# ===== EPOCH : 170 ===== LOSS DIS : 0.48767 ===== LOSS GEN : 1.04108
# ===== EPOCH : 171 ===== LOSS DIS : 0.52201 ===== LOSS GEN : 1.28714
# ===== EPOCH : 172 ===== LOSS DIS : 0.50582 ===== LOSS GEN : 0.82819
# ===== EPOCH : 173 ===== LOSS DIS : 0.41115 ===== LOSS GEN : 1.31222
# ===== EPOCH : 174 ===== LOSS DIS : 0.39845 ===== LOSS GEN : 1.18915
# ===== EPOCH : 175 ===== LOSS DIS : 0.40643 ===== LOSS GEN : 1.18943
# ===== EPOCH : 176 ===== LOSS DIS : 0.38870 ===== LOSS GEN : 1.24114
# ===== EPOCH : 177 ===== LOSS DIS : 0.39765 ===== LOSS GEN : 1.29282
# ===== EPOCH : 178 ===== LOSS DIS : 0.41196 ===== LOSS GEN : 1.20543
# ===== EPOCH : 179 ===== LOSS DIS : 0.35576 ===== LOSS GEN : 1.30734
# ===== EPOCH : 180 ===== LOSS DIS : 0.34362 ===== LOSS GEN : 1.36801
# ===== EPOCH : 181 ===== LOSS DIS : 0.44767 ===== LOSS GEN : 1.00320
# ===== EPOCH : 182 ===== LOSS DIS : 0.39271 ===== LOSS GEN : 1.82987
# ===== EPOCH : 183 ===== LOSS DIS : 0.75251 ===== LOSS GEN : 0.38289
# ===== EPOCH : 184 ===== LOSS DIS : 1.30444 ===== LOSS GEN : 4.98925
# ===== EPOCH : 185 ===== LOSS DIS : 0.48673 ===== LOSS GEN : 1.67758
# ===== EPOCH : 186 ===== LOSS DIS : 0.49410 ===== LOSS GEN : 0.91440
# ===== EPOCH : 187 ===== LOSS DIS : 0.38742 ===== LOSS GEN : 0.98391
# ===== EPOCH : 188 ===== LOSS DIS : 0.34783 ===== LOSS GEN : 1.30807
# ===== EPOCH : 189 ===== LOSS DIS : 0.43098 ===== LOSS GEN : 1.31894
# ===== EPOCH : 190 ===== LOSS DIS : 0.47602 ===== LOSS GEN : 0.99856
# ===== EPOCH : 191 ===== LOSS DIS : 0.47391 ===== LOSS GEN : 1.06312
# ===== EPOCH : 192 ===== LOSS DIS : 0.44516 ===== LOSS GEN : 1.19777
# ===== EPOCH : 193 ===== LOSS DIS : 0.43128 ===== LOSS GEN : 1.15659
# ===== EPOCH : 194 ===== LOSS DIS : 0.39909 ===== LOSS GEN : 1.22543
# ===== EPOCH : 195 ===== LOSS DIS : 0.34748 ===== LOSS GEN : 1.45913
# ===== EPOCH : 196 ===== LOSS DIS : 0.34575 ===== LOSS GEN : 1.44334
# ===== EPOCH : 197 ===== LOSS DIS : 0.39749 ===== LOSS GEN : 1.19411
# ===== EPOCH : 198 ===== LOSS DIS : 0.40564 ===== LOSS GEN : 1.10093
# ===== EPOCH : 199 ===== LOSS DIS : 0.40699 ===== LOSS GEN : 1.30099
# ===== EPOCH : 200 ===== LOSS DIS : 0.39077 ===== LOSS GEN : 1.34887
# ===== EPOCH : 201 ===== LOSS DIS : 0.39123 ===== LOSS GEN : 1.21750
# ===== EPOCH : 202 ===== LOSS DIS : 0.35404 ===== LOSS GEN : 1.29999
# ===== EPOCH : 203 ===== LOSS DIS : 0.32191 ===== LOSS GEN : 1.55728
# ===== EPOCH : 204 ===== LOSS DIS : 0.36568 ===== LOSS GEN : 1.47494
# ===== EPOCH : 205 ===== LOSS DIS : 0.40524 ===== LOSS GEN : 1.01269
# ===== EPOCH : 206 ===== LOSS DIS : 0.42309 ===== LOSS GEN : 1.74875
# ===== EPOCH : 207 ===== LOSS DIS : 0.45994 ===== LOSS GEN : 0.78918
# ===== EPOCH : 208 ===== LOSS DIS : 0.39148 ===== LOSS GEN : 2.23751
# ===== EPOCH : 209 ===== LOSS DIS : 0.37954 ===== LOSS GEN : 1.02249
# ===== EPOCH : 210 ===== LOSS DIS : 0.31947 ===== LOSS GEN : 1.82090
# ===== EPOCH : 211 ===== LOSS DIS : 0.34576 ===== LOSS GEN : 1.50464
# ===== EPOCH : 212 ===== LOSS DIS : 0.35182 ===== LOSS GEN : 1.34405
# ===== EPOCH : 213 ===== LOSS DIS : 0.36035 ===== LOSS GEN : 1.33011
# ===== EPOCH : 214 ===== LOSS DIS : 0.37319 ===== LOSS GEN : 1.93335
# ===== EPOCH : 215 ===== LOSS DIS : 0.48242 ===== LOSS GEN : 0.69783
# ===== EPOCH : 216 ===== LOSS DIS : 0.47122 ===== LOSS GEN : 2.97012
# ===== EPOCH : 217 ===== LOSS DIS : 0.44493 ===== LOSS GEN : 0.87688
# ===== EPOCH : 218 ===== LOSS DIS : 0.33757 ===== LOSS GEN : 1.50779
# ===== EPOCH : 219 ===== LOSS DIS : 0.38807 ===== LOSS GEN : 1.74850
# ===== EPOCH : 220 ===== LOSS DIS : 0.42665 ===== LOSS GEN : 0.99943
# ===== EPOCH : 221 ===== LOSS DIS : 0.38172 ===== LOSS GEN : 1.31939
# ===== EPOCH : 222 ===== LOSS DIS : 0.44235 ===== LOSS GEN : 1.05462
# ===== EPOCH : 223 ===== LOSS DIS : 0.44237 ===== LOSS GEN : 1.44995
# ===== EPOCH : 224 ===== LOSS DIS : 0.46840 ===== LOSS GEN : 1.10006
# ===== EPOCH : 225 ===== LOSS DIS : 0.39814 ===== LOSS GEN : 1.86095
# ===== EPOCH : 226 ===== LOSS DIS : 0.57556 ===== LOSS GEN : 0.60171
# ===== EPOCH : 227 ===== LOSS DIS : 0.60513 ===== LOSS GEN : 3.74708
# ===== EPOCH : 228 ===== LOSS DIS : 0.47369 ===== LOSS GEN : 1.34828
# ===== EPOCH : 229 ===== LOSS DIS : 0.43471 ===== LOSS GEN : 0.99739
# ===== EPOCH : 230 ===== LOSS DIS : 0.43512 ===== LOSS GEN : 1.33544
# ===== EPOCH : 231 ===== LOSS DIS : 0.43807 ===== LOSS GEN : 1.21338
# ===== EPOCH : 232 ===== LOSS DIS : 0.39195 ===== LOSS GEN : 1.28995
# ===== EPOCH : 233 ===== LOSS DIS : 0.37208 ===== LOSS GEN : 1.36363
# ===== EPOCH : 234 ===== LOSS DIS : 0.36998 ===== LOSS GEN : 1.30095
# ===== EPOCH : 235 ===== LOSS DIS : 0.42813 ===== LOSS GEN : 1.03011
# ===== EPOCH : 236 ===== LOSS DIS : 0.41743 ===== LOSS GEN : 1.40400
# ===== EPOCH : 237 ===== LOSS DIS : 0.46911 ===== LOSS GEN : 0.89821
# ===== EPOCH : 238 ===== LOSS DIS : 0.44312 ===== LOSS GEN : 1.43295
# ===== EPOCH : 239 ===== LOSS DIS : 0.44322 ===== LOSS GEN : 0.97945
# ===== EPOCH : 240 ===== LOSS DIS : 0.35166 ===== LOSS GEN : 1.78113
# ===== EPOCH : 241 ===== LOSS DIS : 0.33291 ===== LOSS GEN : 1.15465
# ===== EPOCH : 242 ===== LOSS DIS : 0.27908 ===== LOSS GEN : 2.09605
# ===== EPOCH : 243 ===== LOSS DIS : 0.38392 ===== LOSS GEN : 1.06089
# ===== EPOCH : 244 ===== LOSS DIS : 0.35845 ===== LOSS GEN : 2.41505
# ===== EPOCH : 245 ===== LOSS DIS : 0.45593 ===== LOSS GEN : 1.15105
# ===== EPOCH : 246 ===== LOSS DIS : 0.37438 ===== LOSS GEN : 1.92738
# ===== EPOCH : 247 ===== LOSS DIS : 0.39966 ===== LOSS GEN : 1.31904
# ===== EPOCH : 248 ===== LOSS DIS : 0.43876 ===== LOSS GEN : 1.40689
# ===== EPOCH : 249 ===== LOSS DIS : 0.46361 ===== LOSS GEN : 1.46584
# ===== EPOCH : 250 ===== LOSS DIS : 0.44808 ===== LOSS GEN : 1.04906
# ===== EPOCH : 251 ===== LOSS DIS : 0.33008 ===== LOSS GEN : 2.00193
# ===== EPOCH : 252 ===== LOSS DIS : 0.27232 ===== LOSS GEN : 1.57592
# ===== EPOCH : 253 ===== LOSS DIS : 0.28470 ===== LOSS GEN : 1.39988
# ===== EPOCH : 254 ===== LOSS DIS : 0.32713 ===== LOSS GEN : 1.42558
# ===== EPOCH : 255 ===== LOSS DIS : 0.33777 ===== LOSS GEN : 1.29471
# ===== EPOCH : 256 ===== LOSS DIS : 0.40481 ===== LOSS GEN : 0.98472
# ===== EPOCH : 257 ===== LOSS DIS : 0.34902 ===== LOSS GEN : 2.24311
# ===== EPOCH : 258 ===== LOSS DIS : 0.71904 ===== LOSS GEN : 0.36590
# ===== EPOCH : 259 ===== LOSS DIS : 0.63483 ===== LOSS GEN : 3.32954
# ===== EPOCH : 260 ===== LOSS DIS : 0.45811 ===== LOSS GEN : 0.89979
# ===== EPOCH : 261 ===== LOSS DIS : 0.45307 ===== LOSS GEN : 0.88535
# ===== EPOCH : 262 ===== LOSS DIS : 0.41648 ===== LOSS GEN : 1.72197
# ===== EPOCH : 263 ===== LOSS DIS : 0.39591 ===== LOSS GEN : 1.41784
# ===== EPOCH : 264 ===== LOSS DIS : 0.39161 ===== LOSS GEN : 1.17781
# ===== EPOCH : 265 ===== LOSS DIS : 0.42298 ===== LOSS GEN : 1.37157
# ===== EPOCH : 266 ===== LOSS DIS : 0.38622 ===== LOSS GEN : 1.68587
# ===== EPOCH : 267 ===== LOSS DIS : 0.39378 ===== LOSS GEN : 1.12293
# ===== EPOCH : 268 ===== LOSS DIS : 0.36760 ===== LOSS GEN : 1.33924
# ===== EPOCH : 269 ===== LOSS DIS : 0.35902 ===== LOSS GEN : 1.45387
# ===== EPOCH : 270 ===== LOSS DIS : 0.42156 ===== LOSS GEN : 1.05918
# ===== EPOCH : 271 ===== LOSS DIS : 0.39107 ===== LOSS GEN : 1.44824
# ===== EPOCH : 272 ===== LOSS DIS : 0.37811 ===== LOSS GEN : 1.11193
# ===== EPOCH : 273 ===== LOSS DIS : 0.35473 ===== LOSS GEN : 1.53613
# ===== EPOCH : 274 ===== LOSS DIS : 0.33819 ===== LOSS GEN : 1.31233
# ===== EPOCH : 275 ===== LOSS DIS : 0.36854 ===== LOSS GEN : 1.20686
# ===== EPOCH : 276 ===== LOSS DIS : 0.31775 ===== LOSS GEN : 1.52439
# ===== EPOCH : 277 ===== LOSS DIS : 0.32849 ===== LOSS GEN : 1.27016
# ===== EPOCH : 278 ===== LOSS DIS : 0.32820 ===== LOSS GEN : 1.46588
# ===== EPOCH : 279 ===== LOSS DIS : 0.33807 ===== LOSS GEN : 1.16900
# ===== EPOCH : 280 ===== LOSS DIS : 0.30462 ===== LOSS GEN : 2.02756
# ===== EPOCH : 281 ===== LOSS DIS : 0.41214 ===== LOSS GEN : 0.88819
# ===== EPOCH : 282 ===== LOSS DIS : 0.46999 ===== LOSS GEN : 3.14245
# ===== EPOCH : 283 ===== LOSS DIS : 0.80914 ===== LOSS GEN : 0.30525
# ===== EPOCH : 284 ===== LOSS DIS : 0.44664 ===== LOSS GEN : 2.36254
# ===== EPOCH : 285 ===== LOSS DIS : 0.40804 ===== LOSS GEN : 1.58958
# ===== EPOCH : 286 ===== LOSS DIS : 0.43007 ===== LOSS GEN : 1.02708
# ===== EPOCH : 287 ===== LOSS DIS : 0.44883 ===== LOSS GEN : 1.28914
# ===== EPOCH : 288 ===== LOSS DIS : 0.40322 ===== LOSS GEN : 1.32071
# ===== EPOCH : 289 ===== LOSS DIS : 0.40623 ===== LOSS GEN : 1.14342
# ===== EPOCH : 290 ===== LOSS DIS : 0.39366 ===== LOSS GEN : 1.30346
# ===== EPOCH : 291 ===== LOSS DIS : 0.40205 ===== LOSS GEN : 1.30991
# ===== EPOCH : 292 ===== LOSS DIS : 0.38896 ===== LOSS GEN : 1.24081
# ===== EPOCH : 293 ===== LOSS DIS : 0.38347 ===== LOSS GEN : 1.25045
# ===== EPOCH : 294 ===== LOSS DIS : 0.39032 ===== LOSS GEN : 1.27035
# ===== EPOCH : 295 ===== LOSS DIS : 0.39722 ===== LOSS GEN : 1.23882
# ===== EPOCH : 296 ===== LOSS DIS : 0.37819 ===== LOSS GEN : 1.51989
# ===== EPOCH : 297 ===== LOSS DIS : 0.43874 ===== LOSS GEN : 0.86093
# ===== EPOCH : 298 ===== LOSS DIS : 0.42846 ===== LOSS GEN : 2.23429
# ===== EPOCH : 299 ===== LOSS DIS : 0.51981 ===== LOSS GEN : 0.74672
# ===== EPOCH : 300 ===== LOSS DIS : 0.36972 ===== LOSS GEN : 1.69769
# ===== EPOCH : 301 ===== LOSS DIS : 0.37217 ===== LOSS GEN : 1.49995
# ===== EPOCH : 302 ===== LOSS DIS : 0.40909 ===== LOSS GEN : 1.16306
# ===== EPOCH : 303 ===== LOSS DIS : 0.41993 ===== LOSS GEN : 1.60590
# ===== EPOCH : 304 ===== LOSS DIS : 0.42092 ===== LOSS GEN : 1.27998
# ===== EPOCH : 305 ===== LOSS DIS : 0.38541 ===== LOSS GEN : 1.41804
# ===== EPOCH : 306 ===== LOSS DIS : 0.37902 ===== LOSS GEN : 1.36115
# ===== EPOCH : 307 ===== LOSS DIS : 0.38171 ===== LOSS GEN : 1.21839
# ===== EPOCH : 308 ===== LOSS DIS : 0.36332 ===== LOSS GEN : 1.47887
# ===== EPOCH : 309 ===== LOSS DIS : 0.40613 ===== LOSS GEN : 1.00579
# ===== EPOCH : 310 ===== LOSS DIS : 0.42903 ===== LOSS GEN : 2.47379
# ===== EPOCH : 311 ===== LOSS DIS : 0.78842 ===== LOSS GEN : 0.31073
# ===== EPOCH : 312 ===== LOSS DIS : 0.60037 ===== LOSS GEN : 2.99693
# ===== EPOCH : 313 ===== LOSS DIS : 0.50990 ===== LOSS GEN : 0.98533
# ===== EPOCH : 314 ===== LOSS DIS : 0.46686 ===== LOSS GEN : 0.99122
# ===== EPOCH : 315 ===== LOSS DIS : 0.47043 ===== LOSS GEN : 1.85205
# ===== EPOCH : 316 ===== LOSS DIS : 0.40600 ===== LOSS GEN : 1.28810
# ===== EPOCH : 317 ===== LOSS DIS : 0.41262 ===== LOSS GEN : 1.05937
# ===== EPOCH : 318 ===== LOSS DIS : 0.38486 ===== LOSS GEN : 1.64723
# ===== EPOCH : 319 ===== LOSS DIS : 0.42323 ===== LOSS GEN : 1.19008
# ===== EPOCH : 320 ===== LOSS DIS : 0.39967 ===== LOSS GEN : 1.16642
# ===== EPOCH : 321 ===== LOSS DIS : 0.39913 ===== LOSS GEN : 1.45735
# ===== EPOCH : 322 ===== LOSS DIS : 0.39459 ===== LOSS GEN : 1.11092
# ===== EPOCH : 323 ===== LOSS DIS : 0.36972 ===== LOSS GEN : 1.32318
# ===== EPOCH : 324 ===== LOSS DIS : 0.38553 ===== LOSS GEN : 1.25215
# ===== EPOCH : 325 ===== LOSS DIS : 0.43520 ===== LOSS GEN : 1.01717
# ===== EPOCH : 326 ===== LOSS DIS : 0.43514 ===== LOSS GEN : 2.40459
# ===== EPOCH : 327 ===== LOSS DIS : 0.73101 ===== LOSS GEN : 0.37635
# ===== EPOCH : 328 ===== LOSS DIS : 0.46761 ===== LOSS GEN : 2.89239
# ===== EPOCH : 329 ===== LOSS DIS : 0.43958 ===== LOSS GEN : 1.05859
# ===== EPOCH : 330 ===== LOSS DIS : 0.41219 ===== LOSS GEN : 1.07234
# ===== EPOCH : 331 ===== LOSS DIS : 0.39860 ===== LOSS GEN : 1.49965
# ===== EPOCH : 332 ===== LOSS DIS : 0.40687 ===== LOSS GEN : 1.23914
# ===== EPOCH : 333 ===== LOSS DIS : 0.38906 ===== LOSS GEN : 1.50209
# ===== EPOCH : 334 ===== LOSS DIS : 0.40912 ===== LOSS GEN : 1.26431
# ===== EPOCH : 335 ===== LOSS DIS : 0.43386 ===== LOSS GEN : 1.09552
# ===== EPOCH : 336 ===== LOSS DIS : 0.43406 ===== LOSS GEN : 1.37045
# ===== EPOCH : 337 ===== LOSS DIS : 0.43694 ===== LOSS GEN : 1.01238
# ===== EPOCH : 338 ===== LOSS DIS : 0.39253 ===== LOSS GEN : 1.53839
# ===== EPOCH : 339 ===== LOSS DIS : 0.38811 ===== LOSS GEN : 1.25600
# ===== EPOCH : 340 ===== LOSS DIS : 0.35712 ===== LOSS GEN : 1.54597
# ===== EPOCH : 341 ===== LOSS DIS : 0.35186 ===== LOSS GEN : 1.28468
# ===== EPOCH : 342 ===== LOSS DIS : 0.34342 ===== LOSS GEN : 1.41603
# ===== EPOCH : 343 ===== LOSS DIS : 0.34572 ===== LOSS GEN : 1.40215
# ===== EPOCH : 344 ===== LOSS DIS : 0.35017 ===== LOSS GEN : 1.55691
# ===== EPOCH : 345 ===== LOSS DIS : 0.49567 ===== LOSS GEN : 0.72098
# ===== EPOCH : 346 ===== LOSS DIS : 0.47242 ===== LOSS GEN : 3.06788
# ===== EPOCH : 347 ===== LOSS DIS : 0.85525 ===== LOSS GEN : 0.28618
# ===== EPOCH : 348 ===== LOSS DIS : 0.52435 ===== LOSS GEN : 2.07005
# ===== EPOCH : 349 ===== LOSS DIS : 0.50352 ===== LOSS GEN : 2.14116
# ===== EPOCH : 350 ===== LOSS DIS : 0.42260 ===== LOSS GEN : 1.37520
# ===== EPOCH : 351 ===== LOSS DIS : 0.39843 ===== LOSS GEN : 1.30335
# ===== EPOCH : 352 ===== LOSS DIS : 0.40851 ===== LOSS GEN : 1.65217
# ===== EPOCH : 353 ===== LOSS DIS : 0.43733 ===== LOSS GEN : 0.91256
# ===== EPOCH : 354 ===== LOSS DIS : 0.38370 ===== LOSS GEN : 1.49192
# ===== EPOCH : 355 ===== LOSS DIS : 0.42692 ===== LOSS GEN : 1.23198
# ===== EPOCH : 356 ===== LOSS DIS : 0.39974 ===== LOSS GEN : 1.19254
# ===== EPOCH : 357 ===== LOSS DIS : 0.32531 ===== LOSS GEN : 1.65720
# ===== EPOCH : 358 ===== LOSS DIS : 0.34662 ===== LOSS GEN : 1.36246
# ===== EPOCH : 359 ===== LOSS DIS : 0.33708 ===== LOSS GEN : 1.48947
# ===== EPOCH : 360 ===== LOSS DIS : 0.37306 ===== LOSS GEN : 1.27840
# ===== EPOCH : 361 ===== LOSS DIS : 0.38321 ===== LOSS GEN : 1.46853
# ===== EPOCH : 362 ===== LOSS DIS : 0.35640 ===== LOSS GEN : 1.29338
# ===== EPOCH : 363 ===== LOSS DIS : 0.34645 ===== LOSS GEN : 1.29330
# ===== EPOCH : 364 ===== LOSS DIS : 0.35436 ===== LOSS GEN : 1.38068
# ===== EPOCH : 365 ===== LOSS DIS : 0.37609 ===== LOSS GEN : 1.29870
# ===== EPOCH : 366 ===== LOSS DIS : 0.36335 ===== LOSS GEN : 1.36429
# ===== EPOCH : 367 ===== LOSS DIS : 0.35317 ===== LOSS GEN : 1.26172
# ===== EPOCH : 368 ===== LOSS DIS : 0.41250 ===== LOSS GEN : 0.94985
# ===== EPOCH : 369 ===== LOSS DIS : 0.38311 ===== LOSS GEN : 2.54214
# ===== EPOCH : 370 ===== LOSS DIS : 0.79152 ===== LOSS GEN : 0.34394
# ===== EPOCH : 371 ===== LOSS DIS : 0.46719 ===== LOSS GEN : 3.43620
# ===== EPOCH : 372 ===== LOSS DIS : 0.43369 ===== LOSS GEN : 1.65382
# ===== EPOCH : 373 ===== LOSS DIS : 0.38631 ===== LOSS GEN : 1.13583
# ===== EPOCH : 374 ===== LOSS DIS : 0.40618 ===== LOSS GEN : 1.17524
# ===== EPOCH : 375 ===== LOSS DIS : 0.37682 ===== LOSS GEN : 1.54978
# ===== EPOCH : 376 ===== LOSS DIS : 0.37284 ===== LOSS GEN : 0.97580
# ===== EPOCH : 377 ===== LOSS DIS : 0.35577 ===== LOSS GEN : 1.72550
# ===== EPOCH : 378 ===== LOSS DIS : 0.38289 ===== LOSS GEN : 1.20845
# ===== EPOCH : 379 ===== LOSS DIS : 0.35264 ===== LOSS GEN : 1.38544
# ===== EPOCH : 380 ===== LOSS DIS : 0.36860 ===== LOSS GEN : 1.33813
# ===== EPOCH : 381 ===== LOSS DIS : 0.38146 ===== LOSS GEN : 1.27501
# ===== EPOCH : 382 ===== LOSS DIS : 0.39865 ===== LOSS GEN : 1.20860
# ===== EPOCH : 383 ===== LOSS DIS : 0.36711 ===== LOSS GEN : 1.31262
# ===== EPOCH : 384 ===== LOSS DIS : 0.34717 ===== LOSS GEN : 1.56558
# ===== EPOCH : 385 ===== LOSS DIS : 0.38251 ===== LOSS GEN : 1.13520
# ===== EPOCH : 386 ===== LOSS DIS : 0.36502 ===== LOSS GEN : 1.38404
# ===== EPOCH : 387 ===== LOSS DIS : 0.35648 ===== LOSS GEN : 1.32113
# ===== EPOCH : 388 ===== LOSS DIS : 0.38338 ===== LOSS GEN : 1.18403
# ===== EPOCH : 389 ===== LOSS DIS : 0.33360 ===== LOSS GEN : 1.67329
# ===== EPOCH : 390 ===== LOSS DIS : 0.51723 ===== LOSS GEN : 0.61455
# ===== EPOCH : 391 ===== LOSS DIS : 0.49007 ===== LOSS GEN : 3.41760
# ===== EPOCH : 392 ===== LOSS DIS : 0.57392 ===== LOSS GEN : 0.65583
# ===== EPOCH : 393 ===== LOSS DIS : 0.38469 ===== LOSS GEN : 1.45866
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 18
#      10 dis = DCDiscriminator(features=discriminator_features)
#      12 gan = GAN(generator=gen,
#      13           discriminator=dis,
#      14           loss_fn=BCE_Loss(from_logits=True),
#      15           optimizer_g=Optimizer_Adam(learning_rate=lr, beta_1=0.5),
#      16           optimizer_d=Optimizer_Adam(learning_rate=lr, beta_1=0.5)) # beta1=0.5 !!
# ---> 18 gan.train(X_train, epochs=epochs, print_every=1, batch_size=batch_size)
#
# Cell In[4], line 100, in GAN.train(self, X, epochs, batch_size, print_every)
#      96 for _ in range(1):
#      97
#      98     # Generator forward-backward step
#      99     gen_loss, dis_out = self._generator_forward_step(b_size, real, training=True)
# --> 100     self._generator_backward_step(dis_out, real)
#     102     # Generator parameter update
#     103     self.optimizer_g.pre_update_parameters()
#
# Cell In[4], line 31, in GAN._generator_backward_step(self, discriminator_output, real_labels)
#      29 self.loss_fn.backward(discriminator_output, real_labels)
#      30 #print(f'loss fn sat grad: {np.linalg.norm(self.loss_fn_sat.dinputs)}')
# ---> 31 self.discriminator.backward(self.loss_fn.dinputs)
#      32 #print(f'discriminator grad: {np.linalg.norm(self.discriminator.dinputs)}')
#      33 self.generator.backward(self.discriminator.dinputs)
#
# Cell In[3], line 29, in DCDiscriminator.backward(self, delta)
#      28 def backward(self, delta):
# ---> 29     self.model.backward(delta)
#      30     self.dinputs = self.model.dinputs.copy()
#
# File ~\Documents\Prog\DLFS\dlfs\modules.py:58, in SequentialWrapper.backward(self, delta)
#      55 self.layers[-1].backward(delta)
#      57 for idx, layer in reversed(list(enumerate(self.layers[:-1]))):
# ---> 58     layer.backward(self.layers[idx + 1].dinputs)
#      60 self.dinputs = self.layers[0].dinputs
#
# File ~\Documents\Prog\DLFS\dlfs\layers.py:148, in ConvLayer.backward(self, delta)
#     145 self.dkernels = self.dkernels.reshape(self.kernels.shape)
#     147 self.dinputs = self.K_col.T @ delta_col # (B, C_in*kH*kW, out_H*out_W)
# --> 148 self.dinputs = col2im_strided(self.dinputs,
#     149                       output_shape=(self.H_in, self.W_in),
#     150                       kernel_shape=(kH, kW),
#     151                       stride=self.stride,
#     152                       padding=self.padding) # (B, C_in, H_in, W_in)
#     154 self.dbiases = np.sum(delta_col, axis=(0, 2))
#
# File ~\Documents\Prog\DLFS\dlfs\helpers.py:232, in col2im_strided(cols, output_shape, kernel_shape, stride, padding)
#     228     # final shape: (B, C*kH*kW, L)
#     230     return cols, out_H, out_W
# --> 232 def col2im_strided(cols, output_shape, kernel_shape, stride=1, padding=0):
#     233     B, C_k, L = cols.shape  # C_k = C * kH * kW
#     234     H, W = output_shape
#
# KeyboardInterrupt:

# %%
num_img = 16

fig, axes = plt.subplots(4, 4, figsize=(12, 6))
axes = axes.flatten()

# Sample from random normal
Z = np.random.randn(num_img, gan.generator.latent_dim, 1, 1)

# Pass through decoder to reconstruct
gan.generator.forward(Z)

gan.generator.output = DLFSData.denormalize_MNIST(gan.generator.output, range=(-1, 1))

# Generate and plot n images
for i in range(num_img):
    img = gan.generator.output[i].reshape(28, 28)  # Reshape the output to 28x28 image
    axes[i].imshow(img, cmap='gray')
    axes[i].axis('off')

plt.tight_layout()
plt.show()
